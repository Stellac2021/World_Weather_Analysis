# %%
#Import the dependecies
import pandas as pd
import matplotlib.pyplot as plt
import requests
import numpy as np
import time
from datetime import datetime
from importlib import reload 
from citipy import citipy
from openweather_config import open_weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + open_weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=45214f1a7675a571fcb75b3c3bcc8019

# %%
#Create a list for holding the cities
cities=[]

#Identify the nearest city for eah latitude and longtitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
#print the city count to confir sufficient count
len(cities)
print(cities)
# Out:
# ['amderma', 'tuatapere', 'touros', 'karaton', 'jamestown', 'ushuaia', 'shubarshi', 'butaritari', 'mount gambier', 'ucluelet', 'skelleftea', 'lagoa', 'sao joao da barra', 'bredasdorp', 'yellowknife', 'iguape', 'hithadhoo', 'merauke', 'mataura', 'port lincoln', 'torbay', 'luderitz', 'gombe', 'codrington', 'lolua', 'tiksi', 'yumen', 'umm durman', 'atuona', 'qasigiannguit', 'lang son', 'albany', 'porto novo', 'katangli', 'rikitea', 'yelbarga', 'souillac', 'san felipe', 'prince rupert', 'hilo', 'hermanus', 'tumannyy', 'sacama', 'rancho palos verdes', 'airai', 'independence', 'vaini', 'iberia', 'hambantota', 'pisco', 'walvis bay', 'punta arenas', 'new norfolk', 'kilimatinde', 'narsaq', 'puerto carreno', 'constitucion', 'kapaa', 'geraldton', 'riyadh', 'bethel', 'kichera', 'hasaki', 'coalcoman', 'ancud', 'busselton', 'khatanga', 'coquimbo', 'hobart', 'topolobampo', 'georgetown', 'chuy', 'kaitangata', 'bluff', 'upernavik', 'dawei', 'boende', 'mehamn', 'barrow', 'cape town', 'ostrovnoy', 'shchelyayur', 'vestmannaeyjar', 'itoman', 'lebu', 'port alfred', 'wagar', 'saskylakh', 'kieta', 'katsuura', 'namatanai', 'ponta do sol', 'belushya guba', 'longyearbyen', 'tuktoyaktuk', 'tateyama', 'chokurdakh', 'meulaboh', 'tsihombe', 'ribeira grande', 'taveta', 'korla', 'taltal', 'paka', 'samfya', 'launceston', 'mar del plata', 'cairns', 'pauini', 'quesnel', 'sept-iles', 'meyungs', 'cidreira', 'bargal', 'erenhot', 'nabire', 'bachatskiy', 'mount isa', 'kitgum', 'castro', 'kodiak', 'juneau', 'pundaguitan', 'dikson', 'rimini', 'victoria', 'norman wells', 'banff', 'sola', 'lago da pedra', 'ulladulla', 'santa lucia', 'talcahuano', 'severo-kurilsk', 'oswego', 'barra do garcas', 'bulri', 'kruisfontein', 'carnarvon', 'redlands', 'dingle', 'illoqqortoormiut', 'kisanga', 'bambous virieux', 'artyom', 'leningradskiy', 'guerrero negro', 'majene', 'biggar', 'ambilobe', 'amapa', 'ust-maya', 'sambava', 'thompson', 'provideniya', 'westport', 'la romana', 'taolanaro', 'cherskiy', 'qaanaaq', 'yeppoon', 'kavieng', 'kavali', 'havelock', 'port blair', 'santa vitoria do palmar', 'lavrentiya', 'bemidji', 'buenos aires', 'huaibei', 'vanimo', 'taoudenni', 'phultala', 'khair', 'srednekolymsk', 'la asuncion', 'vao', 'rio grande', 'barstow', 'borovoy', 'tual', 'formosa', 'magadan', 'mayo', 'vila do maio', 'arraial do cabo', 'belaya gora', 'presidencia roque saenz pena', 'cayenne', 'pacific grove', 'rajgarh', 'klyuchi', 'puerto ayora', 'atambua', 'bereda', 'fare', 'filingue', 'mandera', 'springbok', 'zhezkazgan', 'port hawkesbury', 'neropolis', 'inirida', 'fereydun kenar', 'saint-francois', 'koppang', 'skibbereen', 'baykit', 'bathsheba', 'lingao', 'pevek', 'ballina', 'saint-philippe', 'pavlodar', 'watsa', 'grindavik', 'tautira', 'mahebourg', 'porto belo', 'makakilo city', 'sitka', 'manturovo', 'sentyabrskiy', 'fortuna', 'husavik', 'nidzica', 'khumalag', 'devils lake', 'bodden town', 'graham', 'saint-augustin', 'east london', 'kamina', 'grand gaube', 'cubulero', 'sarangani', 'ye', 'horsham', 'balsas', 'pella', 'praia da vitoria', 'rimouski', 'sorvag', 'zhitikara', 'alyangula', 'xinpu', 'halalo', 'nikolskoye', 'beira', 'tahe', 'tolaga bay', 'sisauli', 'tazmalt', 'pathein', 'suntar', 'yanan', 'hornepayne', 'avarua', 'camopi', 'sinkat', 'monrovia', 'milos', 'hofn', 'pyaozerskiy', 'yar-sale', 'andenes', 'constantine', 'bilibino', 'hwange', 'samusu', 'svetlyy', 'chapais', 'krasnoselkup', 'vila velha', 'olafsvik', 'ilulissat', 'hoyanger', 'dandong', 'tianpeng', 'yashalta', 'timmins', 'matola', 'novyy chirkey', 'coihueco', 'kavaratti', 'sirfa', 'farah', 'nantucket', 'barawe', 'lunsar', 'koungheul', 'port elizabeth', 'laguna', 'mbouda', 'osoyoos', 'komsomolskiy', 'richards bay', 'sao gabriel da cachoeira', 'zhanaozen', 'bacuit', 'bend', 'sabha', 'keuruu', 'samarai', 'we', 'nanortalik', 'port hardy', 'bellavista', 'asadabad', 'san patricio', 'casale monferrato', 'prieska', 'manzhouli', 'rovaniemi', 'cururupu', 'bollnas', 'aksu', 'barentsburg', 'nchelenge', 'sangin', 'sorland', 'daru', 'seym ...

# %%
#Create an empty list to hold the weather data
city_data = []

#print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

#Create counters
set_count = 1
record_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Retrieve the following from the API call:
# latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description 
# get the city weather

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        
         # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : current_description})
                          
                          
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | tuatapere
# Processing Record 3 of Set 1 | touros
# Processing Record 4 of Set 1 | karaton
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | shubarshi
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | mount gambier
# Processing Record 10 of Set 1 | ucluelet
# Processing Record 11 of Set 1 | skelleftea
# Processing Record 12 of Set 1 | lagoa
# Processing Record 13 of Set 1 | sao joao da barra
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | iguape
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | merauke
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | port lincoln
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | gombe
# Processing Record 24 of Set 1 | codrington
# Processing Record 25 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | yumen
# Processing Record 28 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | qasigiannguit
# Processing Record 31 of Set 1 | lang son
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | porto novo
# Processing Record 34 of Set 1 | katangli
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | yelbarga
# Processing Record 37 of Set 1 | souillac
# Processing Record 38 of Set 1 | san felipe
# Processing Record 39 of Set 1 | prince rupert
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 1 | sacama
# Processing Record 44 of Set 1 | rancho palos verdes
# Processing Record 45 of Set 1 | airai
# Processing Record 46 of Set 1 | independence
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | iberia
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | pisco
# Processing Record 1 of Set 2 | walvis bay
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | kilimatinde
# Processing Record 5 of Set 2 | narsaq
# Processing Record 6 of Set 2 | puerto carreno
# Processing Record 7 of Set 2 | constitucion
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | geraldton
# Processing Record 10 of Set 2 | riyadh
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | kichera
# Processing Record 13 of Set 2 | hasaki
# Processing Record 14 of Set 2 | coalcoman
# City not found. Skipping...
# Processing Record 15 of Set 2 | ancud
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | topolobampo
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | dawei
# Processing Record 27 of Set 2 | boende
# Processing Record 28 of Set 2 | mehamn
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 2 | vestmannaeyjar
# Processing Record 34 of Set 2 | itoman
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | wagar
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | kieta
# Processing Record 40 of Set 2 | katsuura
# Processing Record 41 of Set 2 | namatanai
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | tateyama
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | meulaboh
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | taveta
# Processing Record 2 of Set 3 | korla
# Processing Record 3 of Set 3 | taltal
# Processing Record 4 of Set 3 | paka
# Processing Record 5 of Set 3 | samfya
# Processing Record 6 of Set 3 | launceston
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | cairns
# Processing Record 9 of Set 3 | pauini
# Processing Record 10 of Set 3 | quesnel
# Processing Record 11 of Set 3 | sept-iles
# Processing Record 12 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 3 | cidreira
# Processing Record 14 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 3 | erenhot
# Processing Record 16 of Set 3 | nabire
# Processing Record 17 of Set 3 | bachatskiy
# Processing Record 18 of Set 3 | mount isa
# Processing Record 19 of Set 3 | kitgum
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | juneau
# Processing Record 23 of Set 3 | pundaguitan
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | rimini
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | banff
# Processing Record 29 of Set 3 | sola
# Processing Record 30 of Set 3 | lago da pedra
# Processing Record 31 of Set 3 | ulladulla
# Processing Record 32 of Set 3 | santa lucia
# Processing Record 33 of Set 3 | talcahuano
# Processing Record 34 of Set 3 | severo-kurilsk
# Processing Record 35 of Set 3 | oswego
# Processing Record 36 of Set 3 | barra do garcas
# Processing Record 37 of Set 3 | bulri
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | redlands
# Processing Record 41 of Set 3 | dingle
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | kisanga
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | artyom
# Processing Record 46 of Set 3 | leningradskiy
# Processing Record 47 of Set 3 | guerrero negro
# Processing Record 48 of Set 3 | majene
# Processing Record 49 of Set 3 | biggar
# Processing Record 50 of Set 3 | ambilobe
# Processing Record 1 of Set 4 | amapa
# Processing Record 2 of Set 4 | ust-maya
# Processing Record 3 of Set 4 | sambava
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | westport
# Processing Record 7 of Set 4 | la romana
# Processing Record 8 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | qaanaaq
# Processing Record 11 of Set 4 | yeppoon
# Processing Record 12 of Set 4 | kavieng
# Processing Record 13 of Set 4 | kavali
# Processing Record 14 of Set 4 | havelock
# Processing Record 15 of Set 4 | port blair
# Processing Record 16 of Set 4 | santa vitoria do palmar
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | bemidji
# Processing Record 19 of Set 4 | buenos aires
# Processing Record 20 of Set 4 | huaibei
# Processing Record 21 of Set 4 | vanimo
# Processing Record 22 of Set 4 | taoudenni
# Processing Record 23 of Set 4 | phultala
# Processing Record 24 of Set 4 | khair
# Processing Record 25 of Set 4 | srednekolymsk
# Processing Record 26 of Set 4 | la asuncion
# Processing Record 27 of Set 4 | vao
# Processing Record 28 of Set 4 | rio grande
# Processing Record 29 of Set 4 | barstow
# Processing Record 30 of Set 4 | borovoy
# Processing Record 31 of Set 4 | tual
# Processing Record 32 of Set 4 | formosa
# Processing Record 33 of Set 4 | magadan
# Processing Record 34 of Set 4 | mayo
# Processing Record 35 of Set 4 | vila do maio
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | belaya gora
# Processing Record 38 of Set 4 | presidencia roque saenz pena
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | pacific grove
# Processing Record 41 of Set 4 | rajgarh
# Processing Record 42 of Set 4 | klyuchi
# Processing Record 43 of Set 4 | puerto ayora
# Processing Record 44 of Set 4 | atambua
# Processing Record 45 of Set 4 | bereda
# Processing Record 46 of Set 4 | fare
# Processing Record 47 of Set 4 | filingue
# Processing Record 48 of Set 4 | mandera
# Processing Record 49 of Set 4 | springbok
# Processing Record 50 of Set 4 | zhezkazgan
# Processing Record 1 of Set 5 | port hawkesbury
# Processing Record 2 of Set 5 | neropolis
# Processing Record 3 of Set 5 | inirida
# Processing Record 4 of Set 5 | fereydun kenar
# Processing Record 5 of Set 5 | saint-francois
# Processing Record 6 of Set 5 | koppang
# Processing Record 7 of Set 5 | skibbereen
# Processing Record 8 of Set 5 | baykit
# Processing Record 9 of Set 5 | bathsheba
# Processing Record 10 of Set 5 | lingao
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | ballina
# Processing Record 13 of Set 5 | saint-philippe
# Processing Record 14 of Set 5 | pavlodar
# Processing Record 15 of Set 5 | watsa
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | tautira
# Processing Record 18 of Set 5 | mahebourg
# Processing Record 19 of Set 5 | porto belo
# Processing Record 20 of Set 5 | makakilo city
# Processing Record 21 of Set 5 | sitka
# Processing Record 22 of Set 5 | manturovo
# Processing Record 23 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | nidzica
# Processing Record 27 of Set 5 | khumalag
# Processing Record 28 of Set 5 | devils lake
# Processing Record 29 of Set 5 | bodden town
# Processing Record 30 of Set 5 | graham
# Processing Record 31 of Set 5 | saint-augustin
# Processing Record 32 of Set 5 | east london
# Processing Record 33 of Set 5 | kamina
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | cubulero
# City not found. Skipping...
# Processing Record 36 of Set 5 | sarangani
# Processing Record 37 of Set 5 | ye
# City not found. Skipping...
# Processing Record 38 of Set 5 | horsham
# Processing Record 39 of Set 5 | balsas
# Processing Record 40 of Set 5 | pella
# Processing Record 41 of Set 5 | praia da vitoria
# Processing Record 42 of Set 5 | rimouski
# Processing Record 43 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 5 | zhitikara
# City not found. Skipping...
# Processing Record 45 of Set 5 | alyangula
# Processing Record 46 of Set 5 | xinpu
# Processing Record 47 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 5 | nikolskoye
# Processing Record 49 of Set 5 | beira
# Processing Record 50 of Set 5 | tahe
# Processing Record 1 of Set 6 | tolaga bay
# Processing Record 2 of Set 6 | sisauli
# Processing Record 3 of Set 6 | tazmalt
# Processing Record 4 of Set 6 | pathein
# Processing Record 5 of Set 6 | suntar
# Processing Record 6 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 6 | hornepayne
# Processing Record 8 of Set 6 | avarua
# Processing Record 9 of Set 6 | camopi
# Processing Record 10 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 6 | monrovia
# Processing Record 12 of Set 6 | milos
# Processing Record 13 of Set 6 | hofn
# Processing Record 14 of Set 6 | pyaozerskiy
# Processing Record 15 of Set 6 | yar-sale
# Processing Record 16 of Set 6 | andenes
# Processing Record 17 of Set 6 | constantine
# Processing Record 18 of Set 6 | bilibino
# Processing Record 19 of Set 6 | hwange
# Processing Record 20 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 6 | svetlyy
# Processing Record 22 of Set 6 | chapais
# Processing Record 23 of Set 6 | krasnoselkup
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | olafsvik
# Processing Record 26 of Set 6 | ilulissat
# Processing Record 27 of Set 6 | hoyanger
# Processing Record 28 of Set 6 | dandong
# Processing Record 29 of Set 6 | tianpeng
# Processing Record 30 of Set 6 | yashalta
# Processing Record 31 of Set 6 | timmins
# Processing Record 32 of Set 6 | matola
# Processing Record 33 of Set 6 | novyy chirkey
# Processing Record 34 of Set 6 | coihueco
# Processing Record 35 of Set 6 | kavaratti
# Processing Record 36 of Set 6 | sirfa
# City not found. Skipping...
# Processing Record 37 of Set 6 | farah
# Processing Record 38 of Set 6 | nantucket
# Processing Record 39 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 6 | lunsar
# Processing Record 41 of Set 6 | koungheul
# Processing Record 42 of Set 6 | port elizabeth
# Processing Record 43 of Set 6 | laguna
# Processing Record 44 of Set 6 | mbouda
# Processing Record 45 of Set 6 | osoyoos
# Processing Record 46 of Set 6 | komsomolskiy
# Processing Record 47 of Set 6 | richards bay
# Processing Record 48 of Set 6 | sao gabriel da cachoeira
# Processing Record 49 of Set 6 | zhanaozen
# Processing Record 50 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 1 of Set 7 | bend
# Processing Record 2 of Set 7 | sabha
# Processing Record 3 of Set 7 | keuruu
# Processing Record 4 of Set 7 | samarai
# Processing Record 5 of Set 7 | we
# City not found. Skipping...
# Processing Record 6 of Set 7 | nanortalik
# Processing Record 7 of Set 7 | port hardy
# Processing Record 8 of Set 7 | bellavista
# Processing Record 9 of Set 7 | asadabad
# Processing Record 10 of Set 7 | san patricio
# Processing Record 11 of Set 7 | casale monferrato
# Processing Record 12 of Set 7 | prieska
# Processing Record 13 of Set 7 | manzhouli
# Processing Record 14 of Set 7 | rovaniemi
# Processing Record 15 of Set 7 | cururupu
# Processing Record 16 of Set 7 | bollnas
# Processing Record 17 of Set 7 | aksu
# Processing Record 18 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 7 | nchelenge
# Processing Record 20 of Set 7 | sangin
# Processing Record 21 of Set 7 | sorland
# Processing Record 22 of Set 7 | daru
# Processing Record 23 of Set 7 | seymchan
# Processing Record 24 of Set 7 | sinnar
# Processing Record 25 of Set 7 | carlsbad
# Processing Record 26 of Set 7 | bantou
# Processing Record 27 of Set 7 | khani
# Processing Record 28 of Set 7 | atbasar
# Processing Record 29 of Set 7 | san anselmo
# Processing Record 30 of Set 7 | goure
# Processing Record 31 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 7 | taber
# Processing Record 33 of Set 7 | luganville
# Processing Record 34 of Set 7 | seoul
# Processing Record 35 of Set 7 | novikovo
# Processing Record 36 of Set 7 | fuyang
# Processing Record 37 of Set 7 | poum
# Processing Record 38 of Set 7 | quelimane
# Processing Record 39 of Set 7 | esperance
# Processing Record 40 of Set 7 | ixtapa
# Processing Record 41 of Set 7 | zuenoula
# Processing Record 42 of Set 7 | havre-saint-pierre
# Processing Record 43 of Set 7 | chiang khong
# Processing Record 44 of Set 7 | los llanos de aridane
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 47 of Set 7 | lazaro cardenas
# Processing Record 48 of Set 7 | abhar
# Processing Record 49 of Set 7 | aripuana
# Processing Record 50 of Set 7 | safford
# Processing Record 1 of Set 8 | dergachi
# Processing Record 2 of Set 8 | namikupa
# Processing Record 3 of Set 8 | corum
# Processing Record 4 of Set 8 | odweyne
# Processing Record 5 of Set 8 | bubaque
# Processing Record 6 of Set 8 | iqaluit
# Processing Record 7 of Set 8 | juarez
# Processing Record 8 of Set 8 | torit
# Processing Record 9 of Set 8 | almaznyy
# Processing Record 10 of Set 8 | necochea
# Processing Record 11 of Set 8 | high prairie
# Processing Record 12 of Set 8 | skerries
# Processing Record 13 of Set 8 | faanui
# Processing Record 14 of Set 8 | bunia
# Processing Record 15 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 16 of Set 8 | salinas
# Processing Record 17 of Set 8 | bengkulu
# Processing Record 18 of Set 8 | sao marcos
# Processing Record 19 of Set 8 | te anau
# Processing Record 20 of Set 8 | pacifica
# Processing Record 21 of Set 8 | mumford
# Processing Record 22 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 8 | kibre mengist
# Processing Record 24 of Set 8 | aykhal
# Processing Record 25 of Set 8 | dulce grande
# Processing Record 26 of Set 8 | zhigansk
# Processing Record 27 of Set 8 | vuktyl
# Processing Record 28 of Set 8 | najran
# Processing Record 29 of Set 8 | gigmoto
# Processing Record 30 of Set 8 | bambanglipuro
# Processing Record 31 of Set 8 | tezu
# Processing Record 32 of Set 8 | nago
# Processing Record 33 of Set 8 | fredericksburg
# Processing Record 34 of Set 8 | urulga
# City not found. Skipping...
# Processing Record 35 of Set 8 | mandurah
# Processing Record 36 of Set 8 | buala
# Processing Record 37 of Set 8 | bahia de caraquez
# Processing Record 38 of Set 8 | boddam
# Processing Record 39 of Set 8 | sao felix do xingu
# Processing Record 40 of Set 8 | parana
# Processing Record 41 of Set 8 | brigantine
# Processing Record 42 of Set 8 | oyugis
# Processing Record 43 of Set 8 | santa fe
# Processing Record 44 of Set 8 | mbanza-ngungu
# Processing Record 45 of Set 8 | rafaela
# Processing Record 46 of Set 8 | hualmay
# Processing Record 47 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 48 of Set 8 | maceio
# Processing Record 49 of Set 8 | lomza
# Processing Record 50 of Set 8 | puerto madero
# Processing Record 1 of Set 9 | joshimath
# Processing Record 2 of Set 9 | aguimes
# Processing Record 3 of Set 9 | faya
# Processing Record 4 of Set 9 | otradnoye
# Processing Record 5 of Set 9 | cabo san lucas
# Processing Record 6 of Set 9 | raudeberg
# Processing Record 7 of Set 9 | opuwo
# Processing Record 8 of Set 9 | caibarien
# Processing Record 9 of Set 9 | port augusta
# Processing Record 10 of Set 9 | pilar
# Processing Record 11 of Set 9 | berdigestyakh
# Processing Record 12 of Set 9 | san quintin
# Processing Record 13 of Set 9 | klyavlino
# Processing Record 14 of Set 9 | san miguel
# Processing Record 15 of Set 9 | beatrice
# Processing Record 16 of Set 9 | auki
# Processing Record 17 of Set 9 | kidal
# Processing Record 18 of Set 9 | tazovskiy
# Processing Record 19 of Set 9 | broome
# Processing Record 20 of Set 9 | zaysan
# Processing Record 21 of Set 9 | puerto el triunfo
# Processing Record 22 of Set 9 | keti bandar
# Processing Record 23 of Set 9 | boden
# Processing Record 24 of Set 9 | saint-pierre
# Processing Record 25 of Set 9 | chato
# Processing Record 26 of Set 9 | adre
# Processing Record 27 of Set 9 | chadiza
# Processing Record 28 of Set 9 | toora-khem
# Processing Record 29 of Set 9 | teahupoo
# Processing Record 30 of Set 9 | takoradi
# Processing Record 31 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 9 | nuuk
# Processing Record 33 of Set 9 | turbat
# Processing Record 34 of Set 9 | santa maria
# Processing Record 35 of Set 9 | maneadero
# Processing Record 36 of Set 9 | masallatah
# Processing Record 37 of Set 9 | ossora
# Processing Record 38 of Set 9 | lynn haven
# Processing Record 39 of Set 9 | lucea
# Processing Record 40 of Set 9 | khingansk
# Processing Record 41 of Set 9 | strezhevoy
# Processing Record 42 of Set 9 | markova
# Processing Record 43 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 9 | qandala
# Processing Record 45 of Set 9 | nola
# Processing Record 46 of Set 9 | shalyhyne
# Processing Record 47 of Set 9 | teykovo
# Processing Record 48 of Set 9 | polson
# Processing Record 49 of Set 9 | nanchang
# Processing Record 50 of Set 9 | san cristobal
# Processing Record 1 of Set 10 | kotdwara
# Processing Record 2 of Set 10 | xuddur
# Processing Record 3 of Set 10 | niceville
# Processing Record 4 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 10 | jalu
# Processing Record 7 of Set 10 | guayabetal
# Processing Record 8 of Set 10 | le port
# Processing Record 9 of Set 10 | sedam
# Processing Record 10 of Set 10 | christchurch
# Processing Record 11 of Set 10 | dzhebariki-khaya
# Processing Record 12 of Set 10 | gari
# Processing Record 13 of Set 10 | iquitos
# Processing Record 14 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 10 | kodinsk
# Processing Record 16 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 10 | sal rei
# Processing Record 18 of Set 10 | ostrowiec swietokrzyski
# Processing Record 19 of Set 10 | kalmunai
# Processing Record 20 of Set 10 | eugene
# Processing Record 21 of Set 10 | gizycko
# Processing Record 22 of Set 10 | buzmeyin
# Processing Record 23 of Set 10 | tasiilaq
# Processing Record 24 of Set 10 | kirakira
# Processing Record 25 of Set 10 | mahibadhoo
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | asfi
# Processing Record 28 of Set 10 | muroto
# Processing Record 29 of Set 10 | saldanha
# Processing Record 30 of Set 10 | sicamous
# Processing Record 31 of Set 10 | hagere hiywet
# Processing Record 32 of Set 10 | buraydah
# Processing Record 33 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 34 of Set 10 | aklavik
# Processing Record 35 of Set 10 | pemba
# Processing Record 36 of Set 10 | carballo
# Processing Record 37 of Set 10 | sisimiut
# Processing Record 38 of Set 10 | salalah
# Processing Record 39 of Set 10 | gainesville
# Processing Record 40 of Set 10 | mikonos
# City not found. Skipping...
# Processing Record 41 of Set 10 | sinnamary
# Processing Record 42 of Set 10 | kamenka
# Processing Record 43 of Set 10 | mpika
# Processing Record 44 of Set 10 | hamilton
# Processing Record 45 of Set 10 | nouadhibou
# Processing Record 46 of Set 10 | tingrela
# City not found. Skipping...
# Processing Record 47 of Set 10 | bury saint edmunds
# City not found. Skipping...
# Processing Record 48 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 10 | beitbridge
# Processing Record 50 of Set 10 | korem
# Processing Record 1 of Set 11 | alta floresta
# Processing Record 2 of Set 11 | alofi
# Processing Record 3 of Set 11 | novotalitsy
# City not found. Skipping...
# Processing Record 4 of Set 11 | margate
# Processing Record 5 of Set 11 | diapaga
# Processing Record 6 of Set 11 | lompoc
# Processing Record 7 of Set 11 | hobyo
# Processing Record 8 of Set 11 | bud
# Processing Record 9 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 10 of Set 11 | niquelandia
# Processing Record 11 of Set 11 | debre tabor
# Processing Record 12 of Set 11 | pudozh
# Processing Record 13 of Set 11 | beloha
# Processing Record 14 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 11 | klaksvik
# Processing Record 16 of Set 11 | arlit
# Processing Record 17 of Set 11 | anloga
# Processing Record 18 of Set 11 | felanitx
# Processing Record 19 of Set 11 | pirot
# Processing Record 20 of Set 11 | rio gallegos
# Processing Record 21 of Set 11 | roros
# Processing Record 22 of Set 11 | tignere
# Processing Record 23 of Set 11 | siparia
# Processing Record 24 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 11 | kuruman
# Processing Record 26 of Set 11 | vallenar
# Processing Record 27 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 11 | krapina
# Processing Record 29 of Set 11 | isangel
# Processing Record 30 of Set 11 | ziway
# Processing Record 31 of Set 11 | naze
# Processing Record 32 of Set 11 | omsukchan
# Processing Record 33 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 11 | lasa
# Processing Record 35 of Set 11 | wanaka
# Processing Record 36 of Set 11 | newport
# Processing Record 37 of Set 11 | saint george
# Processing Record 38 of Set 11 | avera
# Processing Record 39 of Set 11 | yerbogachen
# Processing Record 40 of Set 11 | rock sound
# Processing Record 41 of Set 11 | aguadilla
# Processing Record 42 of Set 11 | aitape
# Processing Record 43 of Set 11 | emba
# Processing Record 44 of Set 11 | taman
# Processing Record 45 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 11 | sivaki
# Processing Record 47 of Set 11 | velingara
# Processing Record 48 of Set 11 | moengo
# Processing Record 49 of Set 11 | fevik
# Processing Record 50 of Set 11 | acapulco
# Processing Record 1 of Set 12 | namibe
# Processing Record 2 of Set 12 | greytown
# Processing Record 3 of Set 12 | caravelas
# Processing Record 4 of Set 12 | pachino
# Processing Record 5 of Set 12 | chimbarongo
# Processing Record 6 of Set 12 | samoylovka
# Processing Record 7 of Set 12 | victor harbor
# Processing Record 8 of Set 12 | carutapera
# Processing Record 9 of Set 12 | abu dhabi
# Processing Record 10 of Set 12 | rudbar
# Processing Record 11 of Set 12 | kaili
# Processing Record 12 of Set 12 | tarakan
# Processing Record 13 of Set 12 | lubango
# Processing Record 14 of Set 12 | rorvik
# Processing Record 15 of Set 12 | san lawrenz
# Processing Record 16 of Set 12 | sarkand
# Processing Record 17 of Set 12 | nan
# Processing Record 18 of Set 12 | talnakh
# Processing Record 19 of Set 12 | turukhansk
# Processing Record 20 of Set 12 | ust-ishim
# Processing Record 21 of Set 12 | kvitok
# Processing Record 22 of Set 12 | skjervoy
# Processing Record 23 of Set 12 | haines junction
# Processing Record 24 of Set 12 | burnie
# Processing Record 25 of Set 12 | boa vista
# Processing Record 26 of Set 12 | grand bank
# Processing Record 27 of Set 12 | college
# Processing Record 28 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 12 | mnogovershinnyy
# Processing Record 30 of Set 12 | paamiut
# Processing Record 31 of Set 12 | muravlenko
# Processing Record 32 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 12 | palu
# Processing Record 34 of Set 12 | asyut
# Processing Record 35 of Set 12 | the valley
# Processing Record 36 of Set 12 | kopargaon
# Processing Record 37 of Set 12 | ahipara
# Processing Record 38 of Set 12 | goundam
# Processing Record 39 of Set 12 | bonavista
# Processing Record 40 of Set 12 | rawson
# Processing Record 41 of Set 12 | laramie
# Processing Record 42 of Set 12 | san carlos de bariloche
# Processing Record 43 of Set 12 | moose factory
# Processing Record 44 of Set 12 | gambo
# Processing Record 45 of Set 12 | north bend
# Processing Record 46 of Set 12 | oak ridge
# Processing Record 47 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 12 | ilebo
# Processing Record 49 of Set 12 | jeremie
# Processing Record 50 of Set 12 | sao filipe
# Processing Record 1 of Set 13 | saint-felicien
# Processing Record 2 of Set 13 | jiangyou
# Processing Record 3 of Set 13 | kedrovyy
# Processing Record 4 of Set 13 | sakaiminato
# Processing Record 5 of Set 13 | salta
# Processing Record 6 of Set 13 | coos bay
# Processing Record 7 of Set 13 | belyy yar
# Processing Record 8 of Set 13 | izazi
# Processing Record 9 of Set 13 | villanueva
# Processing Record 10 of Set 13 | lorengau
# Processing Record 11 of Set 13 | okha
# Processing Record 12 of Set 13 | talaya
# Processing Record 13 of Set 13 | chelyabinsk-70
# City not found. Skipping...
# Processing Record 14 of Set 13 | tuy hoa
# Processing Record 15 of Set 13 | orlik
# Processing Record 16 of Set 13 | larvik
# Processing Record 17 of Set 13 | almora
# Processing Record 18 of Set 13 | fairbanks
# Processing Record 19 of Set 13 | nampula
# Processing Record 20 of Set 13 | metlaltoyuca
# Processing Record 21 of Set 13 | albertville
# Processing Record 22 of Set 13 | pangnirtung
# Processing Record 23 of Set 13 | ascension
# Processing Record 24 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 25 of Set 13 | makokou
# Processing Record 26 of Set 13 | bilma
# Processing Record 27 of Set 13 | morros
# Processing Record 28 of Set 13 | panguna
# Processing Record 29 of Set 13 | coruripe
# Processing Record 30 of Set 13 | glubokoe
# City not found. Skipping...
# Processing Record 31 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 13 | zhongshu
# Processing Record 33 of Set 13 | chivilcoy
# Processing Record 34 of Set 13 | khromtau
# Processing Record 35 of Set 13 | chimbote
# Processing Record 36 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 13 | manaia
# Processing Record 38 of Set 13 | vardo
# Processing Record 39 of Set 13 | collierville
# Processing Record 40 of Set 13 | okhotsk
# Processing Record 41 of Set 13 | saint-joseph
# Processing Record 42 of Set 13 | llanes
# Processing Record 43 of Set 13 | ketchikan
# Processing Record 44 of Set 13 | port keats
# Processing Record 45 of Set 13 | clyde river
# Processing Record 46 of Set 13 | cajamarca
# Processing Record 47 of Set 13 | del rio
# Processing Record 48 of Set 13 | tiznit
# Processing Record 49 of Set 13 | yuli
# Processing Record 50 of Set 13 | ullapool
# Processing Record 1 of Set 14 | nalut
# Processing Record 2 of Set 14 | hermosillo
# Processing Record 3 of Set 14 | pashiya
# Processing Record 4 of Set 14 | jalingo
# Processing Record 5 of Set 14 | karratha
# Processing Record 6 of Set 14 | labuhan
# Processing Record 7 of Set 14 | mandalgovi
# Processing Record 8 of Set 14 | mangrol
# Processing Record 9 of Set 14 | gladstone
# Processing Record 10 of Set 14 | liniere
# City not found. Skipping...
# Processing Record 11 of Set 14 | surt
# Processing Record 12 of Set 14 | linjiang
# Processing Record 13 of Set 14 | orcopampa
# Processing Record 14 of Set 14 | noumea
# Processing Record 15 of Set 14 | mae hong son
# Processing Record 16 of Set 14 | kutum
# Processing Record 17 of Set 14 | dangara
# Processing Record 18 of Set 14 | ayolas
# Processing Record 19 of Set 14 | sirjan
# Processing Record 20 of Set 14 | moerai
# Processing Record 21 of Set 14 | fukuchiyama
# Processing Record 22 of Set 14 | urumqi
# Processing Record 23 of Set 14 | awbari
# Processing Record 24 of Set 14 | chino valley
# Processing Record 25 of Set 14 | sotouboua
# Processing Record 26 of Set 14 | banda aceh
# Processing Record 27 of Set 14 | mogadishu
# Processing Record 28 of Set 14 | shangrao
# Processing Record 29 of Set 14 | mackay
# Processing Record 30 of Set 14 | brae
# Processing Record 31 of Set 14 | siyabuswa
# Processing Record 32 of Set 14 | undory
# Processing Record 33 of Set 14 | nivala
# Processing Record 34 of Set 14 | peruibe
# Processing Record 35 of Set 14 | mount pleasant
# Processing Record 36 of Set 14 | mecca
# Processing Record 37 of Set 14 | kyshtovka
# Processing Record 38 of Set 14 | kapit
# Processing Record 39 of Set 14 | kahului
# Processing Record 40 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 14 | tuxpan
# Processing Record 42 of Set 14 | dongying
# Processing Record 43 of Set 14 | somerset
# Processing Record 44 of Set 14 | eirunepe
# Processing Record 45 of Set 14 | wahlstedt
# Processing Record 46 of Set 14 | boca do acre
# Processing Record 47 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 14 | koslan
# Processing Record 49 of Set 14 | marathon
# Processing Record 50 of Set 14 | sandy bay
# Processing Record 1 of Set 15 | praxedis guerrero
# Processing Record 2 of Set 15 | zaragoza
# Processing Record 3 of Set 15 | shingu
# Processing Record 4 of Set 15 | urgut
# Processing Record 5 of Set 15 | marawi
# Processing Record 6 of Set 15 | mercedes
# Processing Record 7 of Set 15 | malia
# Processing Record 8 of Set 15 | las lomas
# Processing Record 9 of Set 15 | quatre cocos
# Processing Record 10 of Set 15 | changtu
# Processing Record 11 of Set 15 | bay roberts
# Processing Record 12 of Set 15 | caliling
# Processing Record 13 of Set 15 | yurginskoye
# Processing Record 14 of Set 15 | kalengwa
# Processing Record 15 of Set 15 | goderich
# Processing Record 16 of Set 15 | luanda
# Processing Record 17 of Set 15 | ukiah
# Processing Record 18 of Set 15 | fort nelson
# Processing Record 19 of Set 15 | yarmolyntsi
# Processing Record 20 of Set 15 | canutama
# Processing Record 21 of Set 15 | humberto de campos
# Processing Record 22 of Set 15 | lovec
# City not found. Skipping...
# Processing Record 23 of Set 15 | esna
# Processing Record 24 of Set 15 | ayotzintepec
# Processing Record 25 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 26 of Set 15 | grand island
# Processing Record 27 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 15 | zaria
# Processing Record 29 of Set 15 | mapiripan
# Processing Record 30 of Set 15 | xacmaz
# Processing Record 31 of Set 15 | shaunavon
# Processing Record 32 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 15 | batemans bay
# Processing Record 34 of Set 15 | travesia
# Processing Record 35 of Set 15 | la tebaida
# Processing Record 36 of Set 15 | sakakah
# Processing Record 37 of Set 15 | verkhoyansk
# Processing Record 38 of Set 15 | khuzdar
# Processing Record 39 of Set 15 | selenduma
# Processing Record 40 of Set 15 | hailar
# Processing Record 41 of Set 15 | kyaiklat
# Processing Record 42 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 15 | nyandoma
# Processing Record 44 of Set 15 | bugry
# Processing Record 45 of Set 15 | la roda
# Processing Record 46 of Set 15 | agirish
# Processing Record 47 of Set 15 | iranshahr
# Processing Record 48 of Set 15 | ola
# Processing Record 49 of Set 15 | xinyu
# Processing Record 50 of Set 15 | jacareacanga
# Processing Record 1 of Set 16 | mormugao
# Processing Record 2 of Set 16 | bibiani
# Processing Record 3 of Set 16 | malazgirt
# Processing Record 4 of Set 16 | fort-shevchenko
# Processing Record 5 of Set 16 | san juan
# Processing Record 6 of Set 16 | apucarana
# Processing Record 7 of Set 16 | ivanteyevka
# Processing Record 8 of Set 16 | khristoforovo
# City not found. Skipping...
# Processing Record 9 of Set 16 | raymond
# Processing Record 10 of Set 16 | zwiesel
# Processing Record 11 of Set 16 | blythe
# Processing Record 12 of Set 16 | camacupa
# Processing Record 13 of Set 16 | senador jose porfirio
# Processing Record 14 of Set 16 | vredendal
# Processing Record 15 of Set 16 | ilhabela
# Processing Record 16 of Set 16 | pafos
# Processing Record 17 of Set 16 | natal
# Processing Record 18 of Set 16 | dunedin
# Processing Record 19 of Set 16 | manggar
# Processing Record 20 of Set 16 | fonte boa
# Processing Record 21 of Set 16 | mixtequilla
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the weather data to a new DataFrame

weather_data_df = pd.DataFrame(city_data)
weather_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Tuatapere      NZ -46.1333  167.6833     52.83        72          96
# 1       Touros      BR  -5.1989  -35.4608     77.90        82          92
# 2      Karaton      ID  -6.3424  106.1045     86.95        59         100
# 3    Jamestown      US  42.0970  -79.2353     38.08        65          75
# 4      Ushuaia      AR -54.8000  -68.3000     47.86        76          40
# ..         ...     ...      ...       ...       ...       ...         ...
# 699      Pafos      CY  34.7667   32.4167     62.51        63           0
# 700      Natal      BR  -5.7950  -35.2094     77.65       100          75
# 701    Dunedin      NZ -45.8742  170.5036     54.81        75         100
# 702    Manggar      ID  -2.8833  108.2667     83.43        71          87
# 703  Fonte Boa      BR  -2.4959  -66.2662     71.96        98         100
#
#      Wind Speed Current Description
# 0          7.70     overcast clouds
# 1          7.18     overcast clouds
# 2          5.82     overcast clouds
# 3          9.22       broken clouds
# 4         49.48    scattered clouds
# ..          ...                 ...
# 699        6.91           clear sky
# 700        4.61       broken clouds
# 701       10.00     overcast clouds
# 702        9.17     overcast clouds
# 703        1.81     overcast clouds
#
# [704 rows x 9 columns]

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

output_data_file = 'Weather_Database/WeatherPy_Database.csv'
weather_data_df.to_csv(output_data_file, index_label = 'City_ID')
